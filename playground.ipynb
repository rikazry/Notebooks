# %% [markdown]
# A Notebook Quick Start[header 1 with settext style]
# ======================
#
# *Rika's study notes*
#
# 1. Markdown Quick Reference [header 2 with set text style]:
# --------
# ## [Header 2 with atx style]
# ### Headers [header 3]:
# #### closing hash marks are optional for atx style header [header 4] ####
# ###### atx style supports up to 6 levels/ hash marks [header 6]
# ### New line & new paragraph:
# new line needs to be explicite, otherwise:
# This is a new line in code but same line in preview.
# This is a new line in preview if previous line was ended with 2 or more space.
#
# This is a new paragraph in preview if previous line was ended with one or more blank ines.
# ### Emphasis
# rika
# *rika*
# _rika_
# **rika**
# __rika__
# ### Strikethrough
# ~~This is wrong~~
# ### Definition:
# > You only need one > before the first line
# of a hard-wrapped paragraph.
# Remember to end paragraph with blank line to un-quote following text.
#
# >> This is nested definition.
#
# > ####This is nested with header
#
# ### Code:
# This is inline code: `print 'hello word'`
# ```
# # code block wrapped in triple quote
# print 'hello world'
# ```
#     # code block with indentation
#     print 'hello word'
# ### Code Syntax Highlight:
# ```python
# print 'hello world'
# ```
# ### Bulletpoints
# - with -
# * with *
# + with +
#     + indented bulletpoint
#
#
# 1. with number+dot+space
#
# 2\. use \ to escape the indentation and display as pure text
#
# ### Link
# this is [an inline link](https://github.com/rikazry "rika's github"), url can be local relative path.
#
#
# [Rika Profile]: https://github.com/rikazry "rika's github"
# this is [an reference-style link][Rika Profile].
#
# [Rika Profile][]
# ### Auto Link
# <https://github.com/rikazry>
# <rika.zry@gmail.com>
# ### Image
# ![nirvana](http://www.tv543.com/images/cn/nirvana-in-fire.jpg)
# Above is inline image.
# Reference-style image also applies.
# ### Table
# header1|header2|header3
# -|-|-
# 1|2|3
# 4|5|6
# ### Horizontal Rules
# ***
# ___
# ### Note Reference
# [A markdown example](http://blog.zhangruipeng.me/hexo-theme-icarus/2014/12/25/Markdown%20Example/) shows how to write a markdown file.
#
# ## 2. Ipython Notebook Quick Reference:
#
# - ctrl-enter: run cell inplace
# - shift-enter: run cell, jump to next cell below
# - alt-enter: run cell, insert cell below
# - esc: command mode (easy to navigate)
# - k: navigate up
# - j: navigate down
# - dd: delete cell
# - enter: edit mode
# - tab: conde completion
# - ? run: help doc
# - ctrl-m h: keyboard shortcut doc
